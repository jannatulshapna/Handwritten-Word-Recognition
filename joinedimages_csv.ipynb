# %%
import os
import numpy as np

# %%
#extract zip file 


import zipfile
file_name = "/content/full_joined_traindata.zip"
with zipfile.ZipFile(file_name, 'r') as zip:
    zip.extractall()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-1-183ae0d33220> in <module>()
#       4 import zipfile
#       5 file_name = "/content/full_joined_traindata.zip"
# ----> 6 with zipfile.ZipFile(file_name, 'r') as zip:
#       7     zip.extractall()
#       8
#
# /usr/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1129         try:
#    1130             if mode == 'r':
# -> 1131                 self._RealGetContents()
#    1132             elif mode in ('w', 'x'):
#    1133                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.6/zipfile.py in _RealGetContents(self)
#    1196             raise BadZipFile("File is not a zip file")
#    1197         if not endrec:
# -> 1198             raise BadZipFile("File is not a zip file")
#    1199         if self.debug > 1:
#    1200             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
path = '/content/full_joined_traindata'

# %%
list_path = os.listdir(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-94f59948a1f8> in <module>()
# ----> 1 list_path = os.listdir(path)
#
# NameError: name 'os' is not defined

# %%
list_path.sort()

# %%
# append corresponding labels 

lists =[]
for x in range(len(list_path)):
  if x <= 150 :
    lists.append('হতে')

# %%
import csv

# %%
#method 1
import pandas as pd 
df = pd.DataFrame(lists)
df.to_csv('file1.csv', index = False,header = False)

# %%
cnt =0
with open('JoinImagesTrain.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Image_id", "Label"])
    if cnt<=150:
         writer.writerow(["train" + str(cnt)", "হতে"])

    elif cnt<=295:
    writer.writerow(["train" + str(cnt)", "সূর্যমুখী "]) 
      elif cnt<=447:
     writer.writerow(["train" + str(cnt)", "হাজার"]) 
      elif cnt<=619:
       writer.writerow(["train" + str(cnt)", "কাক"])  
       elif cnt<=772:
         writer.writerow(["train" + str(cnt)", "নাম"])
         elif cnt<=939:
          writer.writerow(["train" + str(cnt)", "দেশ"])
          elif cnt<=1092:
            writer.writerow(["train" + str(cnt)", "লোক"])
               elif cnt<=1262:
            writer.writerow(["train" + str(cnt)", "করা"])
                elif cnt<=1419:
                  writer.writerow(["train" + str(cnt)", "ঠান্ডা"])
                  elif cnt<=1572:
                    writer.writerow(["train" + str(cnt)", "সরকার"])
                    elif cnt<=1722:
                        writer.writerow(["train" + str(cnt)", "নেতা"])
                       elif cnt<=1870:
                         writer.writerow(["train" + str(cnt)", "সদস্য"])

                             elif cnt<=2042:
                              writer.writerow(["train" + str(cnt)", "মেয়ে"])
                               elif cnt<=2190:
                                  writer.writerow(["train" + str(cnt)", "ছেলে"])
                                     elif cnt<=2338:
                                       writer.writerow(["train" + str(cnt)", "জেলে"])
                                          
                                          elif cnt<=2505:
                                            writer.writerow(["train" + str(cnt)", "খেলা"])
                                             elif cnt<=2652:
                                                writer.writerow(["train" + str(cnt)", "বাংলাদেশ"])

                                                   elif cnt<=2799:

                                                         writer.writerow(["train" + str(cnt)", "শতাংশ"])
                                                            elif cnt<=2952:
                                                              writer.writerow(["train" + str(cnt)", "আলোচনা"])
                                                                 else:
                                                                   writer.writerow(["train" + str(cnt)", "গবেষণা"])
   


    cnt +=1
# Out:
#   File "<ipython-input-6-1e72b549d6ad>", line 7
#     writer.writerow(["train" + str(cnt)", "হতে"])
#                                           ^
# SyntaxError: invalid syntax

# %%
with open('JoinImagesTrain.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Image_id", "Label"])
    writer.writerow([1, "Linus Torvalds", "Linux Kernel"])
    writer.writerow([2, "Tim Berners-Lee", "World Wide Web"])
    writer.writerow([3, "Guido van Rossum", "Python Programming"])
