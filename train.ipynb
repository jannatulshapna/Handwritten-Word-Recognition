# %%
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from skimage.transform import resize
from skimage.io import imread, imshow
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc

# %% [markdown]
# DATA preparation

# %%
#extract zip file 


import zipfile
file_name = "/content/train.zip"
with zipfile.ZipFile(file_name, 'r') as zip:
    zip.extractall()

# %%
path='/content/train'

# %%
image = os.path.join(path, '/content/train/0')
images = os.listdir(image)
images.sort()
image_len= len(images)
print(image_len)
# Out:
# 50

# %%
mask = os.path.join(path, '/content/train/1')
masks = os.listdir(mask)
masks.sort()
mask_len=len(masks)
print(mask_len)
# Out:
# 50

# %%
height=64
width=64

# %%
x_train = np.zeros((len(images), height, width), dtype=np.uint8)
y_train = np.zeros((len(masks), height, width ), dtype=np.uint8)
print(x_train.shape)
print(y_train.shape)
# Out:
# (50, 64, 64)
# (50, 64, 64)

# %%
sample = '/content/train/1/1.tif'

# %%
#resize images
index = 0
for x in images:
 path = os.path.join(image , x)
 image1 = imread(path)
 image1 = resize(image1, (height, width), mode='constant', preserve_range=True)
 
 x_train[index] = image1
 index += 1
print(x_train.shape)
x_train = x_train / 255
#x_train= np.expand_dims(x_train, axis=-1)

x_train = x_train.astype('float32')
imshow(x_train[0])
print(x_train.dtype)
# Out:
# (50, 64, 64)
# float32
