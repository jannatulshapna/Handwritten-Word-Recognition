# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from skimage.transform import resize
from skimage.io import imread, imshow
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc

# %%
#extract zip file 


import zipfile
file_name = "/content/train.zip"
with zipfile.ZipFile(file_name, 'r') as zip:
    zip.extractall()

# %%
path='/content/test_image_data_0.parquet'

# %%
path = '/content/train'

# %%
image='/content/train/image'

# %%
image = os.path.join(path, '/content/train/image')
images = os.listdir(image)
images.sort()
image_len= len(images)

# %%
imgtha='/content/Train_0.png'
imgthe='/content/Train_1.png'

# %%
import cv2
from matplotlib import pylab as plt
im1 = cv2.imread(imgtha)
im2 =cv2.imread(imgthe)
imshow(im1)

# %%
imshow(im2)

# %%
height = 137
width = 236

# %%
from PIL import Image

# %% [markdown]
# vertical addition link :https://note.nkmk.me/en/python-pillow-concat-images/

# %%
from PIL import Image

im1 = Image.open('/content/Train_0.png')
im2 = Image.open('/content/Train_1.png')

# %%
def get_concat_h_cut(im1, im2):
    dst = Image.new('RGB', (im1.width + im2.width, im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst

# %%
get_concat_h_cut(im1, im2).save('pillow_concat_h_cut1.jpg')

# %%
result = Image. open('/content/pillow_concat_h_cut1.jpg')

# %%
result
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=472x137 at 0x7F0ABA7B4780>

# %%
def get_concat_h(im1, im2):
    dst = Image.new('RGB', (im1.width + im2.width, im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst

# %%
get_concat_h(im1, im1).save('pillow_concat_h.jpg')

# %%
result1 = Image. open('/content/pillow_concat_h.jpg')

# %%
result1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=472x137 at 0x7F0ABA886588>

# %%
def get_concat_h_resize(im1, im2, resample=Image.BICUBIC, resize_big_image=True):
    if im1.height == im2.height:
        _im1 = im1
        _im2 = im2
    elif (((im1.height > im2.height) and resize_big_image) or
          ((im1.height < im2.height) and not resize_big_image)):
        _im1 = im1.resize((int(im1.width * im2.height / im1.height), im2.height), resample=resample)
        _im2 = im2
    else:
        _im1 = im1
        _im2 = im2.resize((int(im2.width * im1.height / im2.height), im1.height), resample=resample)
    dst = Image.new('RGB', (_im1.width + _im2.width, _im1.height))
    dst.paste(_im1, (0, 0))
    dst.paste(_im2, (_im1.width, 0))
    return dst

# %%
get_concat_h_resize(im1, im2).save('pillow_concat_h_resize.jpg')

# %%
result2 = Image. open('pillow_concat_h_resize.jpg')

# %% [markdown]
# https://moonbooks.org/Articles/How-to-merge-images-with-same-size-using-the-python-3-module-pillow-/
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#
# https://www.researchgate.net/post/how_can_i_find_overlapping_area_in_two_gracyscale_images_with_python
#
#
# https://kushalvyas.github.io/stitching.html

# %%
result2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=472x137 at 0x7F0ABA81C160>

# %%
imshow(imgh)

# %%
height =64
width = 64

# %%
new_image1 = imgt.resize((64, 64))

# %%
imgt.shape
# Out:
# (137, 236, 3)

# %%
image = Image.open('/content/train/image/Train_1024.png')
image2 = Image.open('/content/train/image/Train_1025.png')

# %%
print(image.size)
# Out:
# (97, 102)

# %%
img1= image.resize((64, 64))
img1.save('image_64.jpg')
img2= image2.resize((64, 64))
img2.save('image1_64.jpg')

# %%
print(img1.size)
# Out:
# (64, 64)

# %%
print(img2.size)
# Out:
# (64, 64)

# %%
imgs ='/content/image_64.jpg'
imgs1='/content/image1_64.jpg'

# %%
imgf = cv2.imread(imgs)
imgf1 = cv2.imread(imgs1)

# %%
imgf.shape
# Out:
# (64, 64, 3)

# %%
im_h = cv2.hconcat([imgf, imgf1])

# %%
imshow(im_h)

# %%
np.unique(imgt)
from PIL import Image
new_arr = np.zeros((137,236,3),dtype=np.uint8)
np.unique(new_arr)


for index, x in np.ndenumerate(imgt):
    if imgt[index] <= 100:
        new_arr[index] =0
    else:
        new_arr[index] = 255

np.unique(new_arr)

imshow(new_arr)

# %%
im_h = cv2.hconcat([im1, im1])
cv2.imwrite('data/dst/opencv_hconcat.jpg', im_h)

# %%
train_image_0 = pd.read_parquet('/content/test_image_data_0.parquet')

# %%
train_image_1 = pd.read_parquet('/content/test_image_data_1.parquet')

# %%
train_image_0
# Out:
#   image_id    0    1    2    3    4  ...  32326  32327  32328  32329  32330  32331
# 0   Test_0  247  253  253  252  252  ...    254    254    253    253    252    250
# 1   Test_1  253  253  253  253  253  ...    255    255    255    255    255    255
# 2   Test_2  253  253  253  253  253  ...    255    255    255    254    253    252
#
# [3 rows x 32333 columns]

# %%
train_image_0.shape
# Out:
# (3, 32333)

# %% [markdown]
# 37 * 236 = 32332
#
# 0 ~ 255 grayscale data
#
# with image_id

# %%
train_image_0.head()
# Out:
#   image_id    0    1    2    3    4  ...  32326  32327  32328  32329  32330  32331
# 0   Test_0  247  253  253  252  252  ...    254    254    253    253    252    250
# 1   Test_1  253  253  253  253  253  ...    255    255    255    255    255    255
# 2   Test_2  253  253  253  253  253  ...    255    255    255    254    253    252
#
# [3 rows x 32333 columns]

# %%
train_image_data0 = train_image_0.drop('image_id', axis=1)
train_image_data1 = train_image_1.drop('image_id', axis=1)

# %%
train_image_data.head()
# Out:
#      0    1    2    3    4    5  ...  32326  32327  32328  32329  32330  32331
# 0  247  253  253  252  252  252  ...    254    254    253    253    252    250
# 1  253  253  253  253  253  253  ...    255    255    255    255    255    255
# 2  253  253  253  253  253  252  ...    255    255    255    254    253    252
#
# [3 rows x 32332 columns]

# %%
IMAGE_ROW = 137 
IMAGE_COLUMN = 236

img0 = train_image_data0[0:1].values[0].reshape([IMAGE_ROW, IMAGE_COLUMN])
img0
# Out:
# array([[247, 253, 253, ..., 252, 252, 252],
#        [248, 252, 252, ..., 252, 249, 251],
#        [246, 251, 251, ..., 252, 252, 253],
#        ...,
#        [252, 253, 252, ..., 251, 251, 251],
#        [252, 253, 253, ..., 251, 253, 253],
#        [250, 251, 252, ..., 253, 252, 250]], dtype=uint8)

# %%
from matplotlib import pylab as plt

plt.imshow(img0)

# %%
training_images = images[1::2]
training_masks = images[::2]
print(len(training_images)) #20
print(len(training_masks))

# %%
def crop_image_only_outside(img,tol=0):
    # img is 2D or 3D image data
    # tol  is tolerance
    mask = img>tol
    if img.ndim==3:
        mask = mask.all(2)
    m,n = mask.shape
    mask0,mask1 = mask.any(1),mask.any(0)
    col_start,col_end = mask1.argmax(),n-mask1[::-1].argmax()
    row_start,row_end = mask0.argmax(),m-mask0[::-1].argmax()
    return img[row_start:row_end,col_start:col_end]

# %%
cropped = crop_image_only_outside(img0,tol=100)

# %%
imshow(cropped)

# %%
# !pip install pilkit
# Out:
# ...
#      |████████████████████████████████| 163kB 17.5MB/s
# ...
#   Created wheel for pilkit: filename=pilkit-2.0-cp36-none-any.whl size=18294 sha256=949c3eea9975f67f25031665b5fe8374dbf8583219084a9213319026027e500f
#   Stored in directory: /root/.cache/pip/wheels/83/87/b9/db03ec06109a48529da8ba6315550ec177c6d749f50bd85932
# Successfully built pilkit
# ...

# %%
import cv2
import numpy as np

# load image as grayscale
img = cv2.imread(imgtha)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# threshold input image using otsu thresholding as mask and refine with morphology
ret, mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU) 
kernel = np.ones((9,9), np.uint8)
mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

# put mask into alpha channel of image
result = img.copy()
result = cv2.cvtColor(result, cv2.COLOR_BGR2BGRA)
result[:, :, 3] = mask

# save resulting masked image
cv2.imwrite('retina_masked.png', result)

# display result, though it won't show transparency
imr = '/content/retina_masked.png'
cv2.imshow(imr)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-12-14f21ff73331> in <module>()
#      23 # display result, though it won't show transparency
#      24 imr = '/content/retina_masked.png'
# ---> 25 cv2.imshow(imr)
#      26 cv2.waitKey(0)
#      27 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      50   def wrapped(*args, **kwargs):
#      51     if not os.environ.get(env_var, False):
# ---> 52       raise DisabledFunctionError(message, name or func.__name__)
#      53     return func(*args, **kwargs)
#      54
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
def crop_image_only_outside(img0,tol=0):
    # img is 2D image data
    # tol  is tolerance
    mask = img>tol
    m,n = img.shape
    mask0,mask1 = mask.any(0),mask.any(1)
    col_start,col_end = mask0.argmax(),n-mask0[::-1].argmax()
    row_start,row_end = mask1.argmax(),m-mask1[::-1].argmax()
    return img[row_start:row_end,col_start:col_end]

# %%
#Read the image, convert it into grayscale, and make in binary image for threshold value of 1.


gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
_,thresh = cv2.threshold(gray,1,255,cv2.THRESH_BINARY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-29-6ef4841d5aff> in <module>()
#       2
#       3
# ----> 4 gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
#       5 _,thresh = cv2.threshold(gray,1,255,cv2.THRESH_BINARY)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.simd_helpers.hpp:92: error: (-2:Unspecified error) in function 'cv::impl::{anonymous}::CvtHelper<VScn, VDcn, VDepth, sizePolicy>::CvtHelper(cv::InputArray, cv::OutputArray, int) [with VScn = cv::impl::{anonymous}::Set<3, 4>; VDcn = cv::impl::{anonymous}::Set<1>; VDepth = cv::impl::{anonymous}::Set<0, 2, 5>; cv::impl::{anonymous}::SizePolicy sizePolicy = (cv::impl::<unnamed>::SizePolicy)2u; cv::InputArray = const cv::_InputArray&; cv::OutputArray = const cv::_OutputArray&]'
# > Invalid number of channels in input image:
# >     'VScn::contains(scn)'
# > where
# >     'scn' is 1

# %% [markdown]
# **UNET**

# %%
 inputs = Input((row, columns, 3))
s = Lambda(lambda x: x/255) (inputs)
c1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)
c2 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)
c3 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)
c5 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (p4)
c4 = Dropout(0.3) (c4)
c4 = Conv2D(512, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c4)
u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c4)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c6)
u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c7)
u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c8)
u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c9)
outputs = Conv2D(3, (1, 1), activation='sigmoid') (c9)
model = Model(inputs=[inputs], outputs=[outputs])
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
 initial_learning_rate=0.001,
 decay_steps=10000,
 decay_rate=0.5,
 staircase=True)

opt = keras.optimizers.Adam(learning_rate=0.001)
#model.compile(optimizer='adam', loss='binary_crossentropy')
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=[dice_coef, jaccard_index])
model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a5a12f48489> in <module>()
# ----> 1 inputs = Input((row, columns, 3))
#       2 s = Lambda(lambda x: x/255) (inputs)
#       3 c1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (s)
#       4 c1 = Dropout(0.1) (c1)
#       5 c1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same') (c1)
#
# NameError: name 'Input' is not defined
