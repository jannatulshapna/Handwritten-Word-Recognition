# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline
from skimage.transform import resize
from skimage.io import imread, imshow
from tensorflow import keras
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tqdm import tqdm
import gc


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import glob2
import gc
import pyarrow
import time
import math
import skimage
import skimage.measure
import skimage.filters
import scipy
from timeit import timeit
from time import sleep
from pyarrow.parquet import ParquetFile
from typing import Callable
from pandas import DataFrame


from tensorflow.keras.preprocessing.image import ImageDataGenerator
from collections import Counter
from itertools import chain
from functools import reduce

# %%
from PIL import Image

# %%
imgs = '/content/Train_1.png'
imgss = '/content/Train_10.png'

# %%
import cv2
from matplotlib import pylab as plt
img1 = cv2.imread(img)
img2 = cv2.imread(imgss)

imshow(img1)

# %%
imshow(img2)

# %%
resized = cv2.resize(img1, (128,128), interpolation = cv2.INTER_AREA)

# %%
resized1 = cv2.resize(img2, (128,128), interpolation = cv2.INTER_AREA)

# %%
im_h = cv2.hconcat([resized, resized1])

# %%
imshow(im_h)

# %%
def crop_image_only_outside(img,tol=0):
    # img is 2D or 3D image data
    # tol  is tolerance
    mask = img>tol
    if img.ndim==3:
        mask = mask.all(2)
    m,n = mask.shape
    mask0,mask1 = mask.any(1),mask.any(0)
    col_start,col_end = mask1.argmax(),n-mask1[::-1].argmax()
    row_start,row_end = mask0.argmax(),m-mask0[-1::].argmax()
    return img[row_start:row_end,col_start:col_end]

# %%
cropped = crop_image_only_outside(img1,tol=100)

# %%
cropped1 = crop_image_only_outside(img2,tol=150)

# %%
  imshow(cropped)

# %%
# joinning images 
def get_concat_h_resize(im1, im2, resample=Image.BICUBIC, resize_big_image=True):
    if im1.height == im2.height:
        _im1 = im1
        _im2 = im2
    elif (((im1.height > im2.height) and resize_big_image) or
          ((im1.height < im2.height) and not resize_big_image)):
        _im1 = im1.resize((int(im1.width * im2.height / im1.height), im2.height), resample=resample)
        _im2 = im2
    else:
        _im1 = im1
        _im2 = im2.resize((int(im2.width * im1.height / im2.height), im1.height), resample=resample)
    dst = Image.new('RGB', (_im1.width + _im2.width, _im1.height))
    dst.paste(_im1, (0, 0))
    dst.paste(_im2, (_im1.width, 0))
    return dst

# %%
cropped.shape
# Out:
# (90, 70, 3)

# %%
j = imread (img1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-114-e386c7a617f5> in <module>()
# ----> 1 j = imread (img1)
#
# /usr/local/lib/python3.6/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.6/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     208                                (plugin, kind))
#     209
# --> 210     return func(*args, **kwargs)
#     211
#     212
#
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/imageio_plugin.py in imread(*args, **kwargs)
#       8 @wraps(imageio_imread)
#       9 def imread(*args, **kwargs):
# ...

# %%
cropped1.shape
# Out:
# (120, 100, 3)

# %%
im_h = cv2.hconcat([cropped, cropped])

# %%
imshow(im_h)

# %%
cropped.shape
# Out:
# (91, 99, 3)

# %%
for row in range(cropped.getWidth()):
    for col in range(img.getWidth()):
        p = img.getPixel(col, row)

        newred = 255 - p.getRed()
        newgreen = 255 - p.getGreen()
        newblue = 255 - p.getBlue()

        newpixel = image.Pixel(newred, newgreen, newblue)

        img.setPixel(col, row, newpixel)

# %%
result2 = Image. open('pillow_concat_h_resize.jpg')

# %% [markdown]
# https://www.kaggle.com/jamesmcguigan/image-preprocessing/
# https://www.kaggle.com/c/bengaliai-cv19/discussion/134651
# https://www.kaggle.com/maxlenormand/cropping-to-character-resizing-images
# https://www.kaggle.com/rhythmcan/what-s-parquet-file
# https://www.kaggle.com/kaushal2896/resize-and-load-with-feather-format-much-faster

# %%
#resize and load with feather format 
#https://www.kaggle.com/hanjoonchoe/resize-and-load-with-feather-format-much-faster

# %%
np.unique(img1)

im1 = np.zeros((137,236,3),dtype=np.uint8)
np.unique(im1)


for index, x in np.ndenumerate(img1):
    if img1[index] <= 100:
        im1[index] = 0
    else:
        im1[index] = 255

np.unique(im1)

imshow(im1)

# %%
# here you will find the boundary cropping code

#https://www.kaggle.com/jamesmcguigan/bengali-ai-cnn-data-pipeline-problem-solving

# if need more information,please find minst kaggle competition
